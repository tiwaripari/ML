# %% [markdown]
# <a href="https://colab.research.google.com/github/tiwaripari/ML/blob/main/Texttoimagegen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Prompt the user to upload a file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ac9e9792-a5a7-4e6a-b91a-4439b0e844f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac9e9792-a5a7-4e6a-b91a-4439b0e844f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from randomforestemotionclassification import predict_emotion, at_avg
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# training data  295
# testing data  105
#      <input type="file" id="files-ab806941-9500-4963-81a1-b31125bf592f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab806941-9500-4963-81a1-b31125bf592f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
audio_file = '/content/Peaceful.mp3'
attribute_avg = at_avg()

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/SG161222/Realistic_Vision_V1.4"
headers = {"Authorization": "Bearer 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"}


def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content

emotion = {
    'happy': 'Create art that represents happiness.',
    'sad': 'Create art that conveys sadness.',
    'angry': 'Create art that depicts anger.',
    'relax' : 'Create art that depicts relax.'
    
}

pred_emotion = predict_emotion(audio_file, attribute_avg)
print(pred_emotion)
image_bytes = query({
	"inputs": emotion[pred_emotion]
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))
# Out:
# /content/finalmusicfeatureextractednew.py:131: RuntimeWarning: divide by zero encountered in log2
#   features['_HarmonicChangeDetectionFunction_PeriodEntropy'] = -np.sum(periodicity * np.log2(periodicity)) / np.sum(periodicity)
# /content/finalmusicfeatureextractednew.py:131: RuntimeWarning: invalid value encountered in log2
#   features['_HarmonicChangeDetectionFunction_PeriodEntropy'] = -np.sum(periodicity * np.log2(periodicity)) / np.sum(periodicity)
# /content/finalmusicfeatureextractednew.py:131: RuntimeWarning: invalid value encountered in multiply
#   features['_HarmonicChangeDetectionFunction_PeriodEntropy'] = -np.sum(periodicity * np.log2(periodicity)) / np.sum(periodicity)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1047: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# ...

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F1D7BCC3A90>
